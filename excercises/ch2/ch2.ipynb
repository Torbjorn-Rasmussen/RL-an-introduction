# %%
import numpy as np
import matplotlib.pyplot as plt
from dataclasses import dataclass
from typing import Optional
import tqdm

# %% [markdown]
# # env and agent

# %%
@dataclass
class Bandit():
    mean: float
    var: float
    seed: Optional[int] = None

    def __post_init__(self):
        self.rng = np.random.default_rng(self.seed)
    
    def pull(self):
        return self.rng.normal(self.mean, self.var)
    
class BanditProblem():
    def __init__(self, k: int, starting_mean = 0, starting_var = 1, seed = None):
        self.rng = np.random.default_rng(seed)
        self.bandit_means = self.rng.normal(starting_mean, starting_var, k)
        self.bandits = [Bandit(bandit_mean, starting_var) for bandit_mean in self.bandit_means]

    def pull(self, bandit_idx):
        return self.bandits[bandit_idx].pull()

    def get_optimal_bandit(self):
        return np.argmax([bandit.mean for bandit in self.bandits])
    
    def update_bandit_means(self, ):
        self.bandit_means += self.rng.normal(0, 0.01, len(self.bandit_means))
        for i, bandit in enumerate(self.bandits):
            bandit.mean = self.bandit_means[i]
        

class BanditAgentEpsilonGreedy():
    def __init__(self, k: int, epsilon: float = 0.1, alpha: float = None, seed=None):
        self.k = k
        self.epsilon = epsilon
        self.alpha = alpha
        self.q = np.zeros(k)
        self.n = np.zeros(k)
        self.rng = np.random.default_rng(seed)

    def choose_action(self):
        if self.rng.random() < self.epsilon:
            return self.rng.integers(0, self.k)
        else:
            return np.argmax(self.q)

    def update(self, action, reward):
        self.n[action] += 1
        if self.alpha is None: # Sample-average method
            self.q[action] += (reward - self.q[action]) / self.n[action]
        else: # Constant step-size method
            self.q[action] += self.alpha * (reward - self.q[action])

# %%
def perform_strategy(bandit_pairs, update = False):
    for pair_id, pair in bandit_pairs.items():
        bandit_problem = pair['bandit_problem']
        bandit_agent = pair['bandit_agent']

        action = bandit_agent.choose_action()
        reward = bandit_problem.pull(action)

        bandit_agent.update(action, reward)
        
        pair['actions'].append(action)
        pair['rewards'].append(reward)
        pair['optimal_choice'].append(action == bandit_problem.get_optimal_bandit())
        if update:
            bandit_problem.update_bandit_means()

def get_averages(bandit_pairs):
    avg_rewards = np.array([pair['rewards'] for pair in bandit_pairs.values()])
    avg_rewards = np.mean(avg_rewards, axis=0)

    avg_optimal_choice = np.array([pair['optimal_choice'] for pair in bandit_pairs.values()])
    avg_optimal_choice = np.mean(avg_optimal_choice, axis=0)

    return avg_rewards, avg_optimal_choice

# %% [markdown]
# # Stationary problem

# %%
k = 10
bandit_pairs_eps0 = {str(pair_id):{'bandit_problem': BanditProblem(k), 'bandit_agent': BanditAgentEpsilonGreedy(k, epsilon=0),
                'actions':[], 'rewards':[], 'optimal_choice': []}
                for pair_id in range(2000)}

bandit_pairs_eps01 = {str(pair_id):{'bandit_problem': BanditProblem(k), 'bandit_agent': BanditAgentEpsilonGreedy(k, epsilon=0.1),
                'actions':[], 'rewards':[], 'optimal_choice': []}
                for pair_id in range(2000)}

bandit_pairs_eps001 = {str(pair_id):{'bandit_problem': BanditProblem(k), 'bandit_agent': BanditAgentEpsilonGreedy(k, epsilon=0.01),
                        'actions':[], 'rewards':[], 'optimal_choice': []}
                        for pair_id in range(2000)}

n_steps = 1000

for i in tqdm.tqdm(range(n_steps)):
    perform_strategy(bandit_pairs_eps0)
    perform_strategy(bandit_pairs_eps01)
    perform_strategy(bandit_pairs_eps001)
# Out:
# 100%|██████████| 1000/1000 [01:22<00:00, 12.19it/s]

# %%
avg_rewards_eps0, avg_optimal_choice_eps0 = get_averages(bandit_pairs_eps0)
avg_rewards_eps01, avg_optimal_choice_eps01 = get_averages(bandit_pairs_eps01)
avg_rewards_eps001, avg_optimal_choice_eps001 = get_averages(bandit_pairs_eps001)

fig, axes = plt.subplots(nrows=2)
axes[0].plot(avg_rewards_eps0, label='epsilon=0')
axes[0].plot(avg_rewards_eps01, label='epsilon=0.1')
axes[0].plot(avg_rewards_eps001, label='epsilon=0.01')
axes[0].set_title('Average reward')
axes[0].legend()
axes[0].set_xticklabels([])
axes[1].plot(avg_optimal_choice_eps0, label='epsilon=0')
axes[1].plot(avg_optimal_choice_eps01, label='epsilon=0.1')
axes[1].plot(avg_optimal_choice_eps001, label='epsilon=0.01')
axes[1].set_title('Optimal choice')
axes[1].legend()

fig.suptitle('Stationary bandit problem')
# Out:
# Text(0.5, 0.98, 'Stationary bandit problem')

# %% [markdown]
# # None stationary problem

# %%
k = 10
bandit_pairs_eps0 = {str(pair_id):{'bandit_problem': BanditProblem(k), 'bandit_agent': BanditAgentEpsilonGreedy(k, epsilon=0),
                'actions':[], 'rewards':[], 'optimal_choice': []}
                for pair_id in range(2000)}

bandit_pairs_eps01 = {str(pair_id):{'bandit_problem': BanditProblem(k), 'bandit_agent': BanditAgentEpsilonGreedy(k, epsilon=0.1),
                'actions':[], 'rewards':[], 'optimal_choice': []}
                for pair_id in range(2000)}

bandit_pairs_eps001 = {str(pair_id):{'bandit_problem': BanditProblem(k), 'bandit_agent': BanditAgentEpsilonGreedy(k, epsilon=0.01),
                        'actions':[], 'rewards':[], 'optimal_choice': []}
                        for pair_id in range(2000)}

n_steps = 1000

for i in tqdm.tqdm(range(n_steps)):
    perform_strategy(bandit_pairs_eps0, update=True)
    perform_strategy(bandit_pairs_eps01, update=True)
    perform_strategy(bandit_pairs_eps001, update=True)
# Out:
# 100%|██████████| 1000/1000 [01:48<00:00,  9.21it/s]

# %%
avg_rewards_eps0, avg_optimal_choice_eps0 = get_averages(bandit_pairs_eps0)
avg_rewards_eps01, avg_optimal_choice_eps01 = get_averages(bandit_pairs_eps01)
avg_rewards_eps001, avg_optimal_choice_eps001 = get_averages(bandit_pairs_eps001)

fig, axes = plt.subplots(nrows=2)
axes[0].plot(avg_rewards_eps0, label='epsilon=0')
axes[0].plot(avg_rewards_eps01, label='epsilon=0.1')
axes[0].plot(avg_rewards_eps001, label='epsilon=0.01')
axes[0].set_title('Average reward')
axes[0].legend()
axes[0].set_xticklabels([])
axes[1].plot(avg_optimal_choice_eps0, label='epsilon=0')
axes[1].plot(avg_optimal_choice_eps01, label='epsilon=0.1')
axes[1].plot(avg_optimal_choice_eps001, label='epsilon=0.01')
axes[1].set_title('Optimal choice')
axes[1].legend()

fig.suptitle('None Stationary bandit problem')
# Out:
# Text(0.5, 0.98, 'None Stationary bandit problem')

# %% [markdown]
# # exc 2.5 solution

# %%
k = 10

bandit_pairs_sample_average = {str(pair_id):{'bandit_problem': BanditProblem(k), 'bandit_agent': BanditAgentEpsilonGreedy(k, epsilon=0.1),
                'actions':[], 'rewards':[], 'optimal_choice': []}
                for pair_id in range(2000)}

bandit_pairs_alpha = {str(pair_id):{'bandit_problem': BanditProblem(k), 'bandit_agent': BanditAgentEpsilonGreedy(k, alpha = 0.1, epsilon=0.1),
                'actions':[], 'rewards':[], 'optimal_choice': []}
                for pair_id in range(2000)}


n_steps = 5000

for i in tqdm.tqdm(range(n_steps)):
    perform_strategy(bandit_pairs_sample_average, update=True)
    perform_strategy(bandit_pairs_alpha, update=True)
# Out:
#   0%|          | 20/5000 [00:01<06:34, 12.61it/s]
# 100%|██████████| 5000/5000 [07:00<00:00, 11.90it/s]

# %%
avg_rewards_sample_average, avg_optimal_choice_sample_average = get_averages(bandit_pairs_sample_average)
avg_rewards_alpha, avg_optimal_choice_alpha = get_averages(bandit_pairs_alpha)

fig, axes = plt.subplots(nrows=2)
axes[0].plot(avg_rewards_sample_average, label='sample_average')
axes[0].plot(avg_rewards_alpha, label='alpha')
axes[0].set_title('Average reward')
axes[0].legend()
axes[0].set_xticklabels([])

axes[1].plot(avg_optimal_choice_sample_average, label='sample_average')
axes[1].plot(avg_optimal_choice_alpha, label='alpha')
axes[1].set_title('Optimal choice')
axes[1].legend()

fig.suptitle('None Stationary, sample average vs constant step size')
# Out:
# Text(0.5, 0.98, 'None Stationary, sample average vs constant step size')

# %% [markdown]
# # different types of agents

# %%
class BanditAgentUCB():
    def __init__(self, k: int, c = 1, alpha: float = None, seed=None):
        self.k = k
        self.c = c
        self.alpha = alpha
        self.q = np.zeros(k)
        self.n = np.zeros(k)
        self.rng = np.random.default_rng(seed)

    def choose_action(self):
        vals = self.q + self.c * np.sqrt(np.log(np.sum(self.n)) / self.n)
        return np.argmax(vals)

    def update(self, action, reward):
        self.n[action] += 1
        if self.alpha is None: # Sample-average method
            self.q[action] += (reward - self.q[action]) / self.n[action]
        else: # Constant step-size method
            self.q[action] += self.alpha * (reward - self.q[action])

from copy import deepcopy
class BanditAgentGradient():
    def __init__(self, k: int, alpha=0.1, alpha_average=None, avg_reward_init = 1, seed=None):
        self.k = k
        self.n = np.zeros(k)
        self.rng = np.random.default_rng(seed)
        self.alpha = alpha
        self.alpha_average = alpha_average

        # self.p_vals = np.ones(k) / k
        self.h_vals = np.zeros(k)
        self.avg_reward = avg_reward_init

    def choose_action(self):
        p_vals = self.calc_probs()
        return self.rng.choice(self.k, p = p_vals)
    
    def calc_probs(self):
        exp_vals = np.exp(self.h_vals)
        return exp_vals / np.sum(exp_vals)
    
    def update(self, action, reward):
        pi_t = deepcopy(self.h_vals)
        for i in range(self.k):
            if i == action:
                self.h_vals[i] += self.alpha * (reward - self.avg_reward) * (1 - pi_t[i])
            else:
                self.h_vals[i] -= self.alpha * (reward - self.avg_reward) * pi_t[i]

        self.update_avg_reward(reward)

    def update_avg_reward(self, reward):
        if self.alpha_average is None:
            self.avg_reward += (reward - self.avg_reward) / np.sum(self.n)
        else:
            self.avg_reward += self.alpha_average * (reward - self.avg_reward)

# %%
k = 10
eps_greed_rewards = []
ucb_rewards = []
gradient_rewards = []

epsilons = [0.2, 0.1, 0.05, 0.01]
cs = [4, 2, 1, 0.5]
alphas = [0.2, 0.1 , 0.05, 0.01]
for eps, c, alpha in zip(epsilons, cs, alphas):

    bandit_pairs_BanditAgentEpsilonGreedy = {str(pair_id):{'bandit_problem': BanditProblem(k), 'bandit_agent': BanditAgentEpsilonGreedy(k, alpha = 0.1, epsilon=eps),
                    'actions':[], 'rewards':[], 'optimal_choice': []}
                    for pair_id in range(1000)}

    bandit_pairs_BanditAgentUCB = {str(pair_id):{'bandit_problem': BanditProblem(k), 'bandit_agent': BanditAgentUCB(k, c=c),
                                'actions':[], 'rewards':[], 'optimal_choice': []}
                                for pair_id in range(1000)}

    bandit_pairs_BanditAgentGradient = {str(pair_id):{'bandit_problem': BanditProblem(k), 'bandit_agent': BanditAgentGradient(k, alpha=alpha, alpha_average=0.1),
                                'actions':[], 'rewards':[], 'optimal_choice': []}
                                for pair_id in range(1000)}


    n_steps = 1000

    for i in tqdm.tqdm(range(n_steps)):
        perform_strategy(bandit_pairs_BanditAgentEpsilonGreedy, update=True)
        perform_strategy(bandit_pairs_BanditAgentUCB, update=True)
        perform_strategy(bandit_pairs_BanditAgentGradient, update=True)


    avg_rewards_epsilongreedy, avg_optimal_choice_epsilongreedy = get_averages(bandit_pairs_BanditAgentEpsilonGreedy)
    avg_rewards_ucb, avg_optimal_choice_ucb = get_averages(bandit_pairs_BanditAgentUCB)
    avg_rewards_gradient, avg_optimal_choice_gradient = get_averages(bandit_pairs_BanditAgentGradient)

    eps_greed_rewards.append(np.mean(avg_rewards_epsilongreedy[500:]))
    ucb_rewards.append(np.mean(avg_rewards_ucb[500:]))
    gradient_rewards.append(np.mean(avg_rewards_gradient[500:]))
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]/var/folders/7r/69xsn2cj26d4vp_yr8pvrm2c0000gn/T/ipykernel_49449/1526743165.py:11: RuntimeWarning: divide by zero encountered in log
#   vals = self.q + self.c * np.sqrt(np.log(np.sum(self.n)) / self.n)
# /var/folders/7r/69xsn2cj26d4vp_yr8pvrm2c0000gn/T/ipykernel_49449/1526743165.py:11: RuntimeWarning: invalid value encountered in sqrt
#   vals = self.q + self.c * np.sqrt(np.log(np.sum(self.n)) / self.n)
#   0%|          | 1/1000 [00:00<02:12,  7.54it/s]/var/folders/7r/69xsn2cj26d4vp_yr8pvrm2c0000gn/T/ipykernel_49449/1526743165.py:11: RuntimeWarning: invalid value encountered in divide
#   vals = self.q + self.c * np.sqrt(np.log(np.sum(self.n)) / self.n)
#   0%|          | 2/1000 [00:00<02:06,  7.87it/s]/var/folders/7r/69xsn2cj26d4vp_yr8pvrm2c0000gn/T/ipykernel_49449/1526743165.py:11: RuntimeWarning: divide by zero encountered in divide
#   vals = self.q + self.c * np.sqrt(np.log(np.sum(self.n)) / self.n)
# 100%|██████████| 1000/1000 [02:02<00:00,  8.17it/s]
# 100%|██████████| 1000/1000 [02:04<00:00,  8.04it/s]
# 100%|██████████| 1000/1000 [02:02<00:00,  8.17it/s]
# 100%|██████████| 1000/1000 [01:59<00:00,  8.38it/s]

# %%
fig, ax = plt.subplots()

ax.plot(np.log(epsilons), eps_greed_rewards, label='Epsilon greedy')
ax.plot(np.log(cs), ucb_rewards, label='UCB')
ax.plot(np.log(alphas), gradient_rewards, label='Gradient')
ax.set_title('Average reward')
ax.legend()
ax.set_xlabel('log(epsilon/c/alpha)')
ax.set_ylabel('Average reward')
# Out:
# Text(0, 0.5, 'Average reward')

# %%
avg_rewards_epsilongreedy, avg_optimal_choice_epsilongreedy = get_averages(bandit_pairs_BanditAgentEpsilonGreedy)
avg_rewards_ucb, avg_optimal_choice_ucb = get_averages(bandit_pairs_BanditAgentUCB)
avg_rewards_gradient, avg_optimal_choice_gradient = get_averages(bandit_pairs_BanditAgentGradient)



fig, axes = plt.subplots(nrows=2)
axes[0].plot(avg_rewards_epsilongreedy, label='epsilon-greedy')
axes[0].plot(avg_rewards_ucb, label='ucb')
axes[0].plot(avg_rewards_gradient, label='gradient')
axes[0].set_title('Average reward')
axes[0].legend()
axes[0].set_xticklabels([])

axes[1].plot(avg_optimal_choice_epsilongreedy, label='epsilon-greedy')
axes[1].plot(avg_optimal_choice_ucb, label='ucb')
axes[1].plot(avg_optimal_choice_gradient, label='gradient')
axes[1].set_title('Optimal choice')
axes[1].legend()

fig.suptitle('None Stationary, sample average vs constant step size')
# Out:
# Text(0.5, 0.98, 'None Stationary, sample average vs constant step size')
